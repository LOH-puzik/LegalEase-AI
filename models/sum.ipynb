# %%
import torch
from transformers import pipeline

# %%
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.0.1
# 11.8
# True

# %%
from transformers import BertTokenizerFast, pipeline

# Initialize the tokenizer
bert_tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")

# Initialize the summarizer
bert_summarizer = pipeline("summarization", device=0)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
import re

def clean_text(file_path):
    with open(file_path, 'r') as f:
        text = f.read()

    patterns = [
        (r'\n([0-9]+)\n', r' \1 ', None),
        (r'\n', ' ', None),
        (r"(?<!\w)'|'(?!\w)", ' ', None)
    ]

    for pattern, replacement, flags in patterns:
        text = re.sub(pattern, replacement, text, flags=flags if flags else 0)

    return text

file_paths = ['../data/text_l1.txt', '../data/text_l2.txt', '../data/text_l3.txt']
texts = {}

for file_path in file_paths:
    # Split the file_path to get the base name, then remove the extension to get the variable name
    var_name = file_path.split('/')[-1].split('.')[0]
    # Store the cleaned text in the dictionary with the variable name as the key
    texts[var_name] = clean_text(file_path)

print(texts['text_l3'][:1000])
# Out:
# 1 EN Council of the European Union General Conditions General Secretariat June 2016 - EN GENERAL CONDITIONS OF THE CONTRACT The contract consists of a purchase order and these general conditions, including the Annex on security measures. If there is any conflict between different provisions in the contract, the following rules must be applied: (a) the provisions set out in the purchase order take precedence over those set out in the general conditions; (b) the provisions set out in the general conditions take precedence over those set out in the tender specifications; (c) the provisions set out in the tender specifications take precedence over those set out in the contractor's tender. All documents issued by the contractor (end-user agreements, general terms and conditions, etc.), with the exception of its tender, are held inapplicable, unless explicitly mentioned in the special conditions of the contract. In all circumstances, in the event of contradiction between the contract and doc

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Measure the length of a text
def bert_len(text):
    tokens = bert_tokenizer.encode(
        text,
        add_special_tokens=True,
        max_length=len(text),
        truncation=True
    )
    return len(tokens)

# Text splitter initialization
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,  
    chunk_overlap=30,
    length_function=bert_len,
    separators=[". ", ""]
)

def remove_duplicates(text):
    # Remove duplicate sentences from the text
    seen = set()
    return ". ".join([sentence for sentence in text.split(". ") if sentence not in seen and not seen.add(sentence)])

def generate_summary(text):
    # Summarize the text
    summary = bert_summarizer(text, max_length=500, min_length=25, do_sample=False)

    return summary[0]['summary_text']

def summarize_large_text(text):
    # Split the text into chunks
    chunks = text_splitter.split_text(text)

    # Summarize each chunk
    chunk_summaries = [generate_summary(chunk) for chunk in chunks]

    # Concatenate the chunk summaries
    text = ". ".join(chunk_summaries)

    # Remove duplicates
    text = remove_duplicates(text)

    return text

large_text = texts['text_l3']
summarized_text = summarize_large_text(large_text)
final_text = summarized_text

# Check if the summarized text length is over 4000 words
while len(final_text.split()) > 4000:
    final_text = summarize_large_text(final_text)
# Out:
# Your max_length is set to 500, but you input_length is only 462. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=231)
# Your max_length is set to 500, but you input_length is only 366. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=183)
# Your max_length is set to 500, but you input_length is only 462. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=231)
# Your max_length is set to 500, but you input_length is only 413. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=206)
# Your max_length is set to 500, but you input_length is only 418. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=209)
# Your max_length is set to 500, but you input_length is only 438. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=219)
# Your max_length is set to 500, but you input_length is only 436. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=218)
# Your max_length is set to 500, but you input_length is only 421. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=210)
# Your max_length is set to 500, but you input_length is only 431. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=215)
# Your max_length is set to 500, but you input_length is only 415. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=207)
# C:\Users\Dhia\AppData\Roaming\Python\Python310\site-packages\transformers\pipelines\base.py:1043: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Your max_length is set to 500, but you input_length is only 458. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=229)
# Your max_length is set to 500, but you input_length is only 425. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=212)
# Your max_length is set to 500, but you input_length is only 447. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=223)
# Your max_length is set to 500, but you input_length is only 370. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=185)
# Your max_length is set to 500, but you input_length is only 447. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=223)
# Your max_length is set to 500, but you input_length is only 467. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=233)
# Your max_length is set to 500, but you input_length is only 430. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=215)
# Your max_length is set to 500, but you input_length is only 319. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=159)
# Your max_length is set to 500, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 22. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 22. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 500, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 18. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
# Your max_length is set to 500, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 17. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 26. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 500, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 500, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 500, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 500, but you input_length is only 5. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 500, but you input_length is only 451. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=225)
# Your max_length is set to 500, but you input_length is only 452. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=226)
# Your max_length is set to 500, but you input_length is only 434. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Your max_length is set to 500, but you input_length is only 445. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=222)
# Your max_length is set to 500, but you input_length is only 242. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=121)
# Your max_length is set to 500, but you input_length is only 434. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Your max_length is set to 500, but you input_length is only 452. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=226)
# Your max_length is set to 500, but you input_length is only 454. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=227)
# Your max_length is set to 500, but you input_length is only 434. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=217)
# Your max_length is set to 500, but you input_length is only 451. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=225)
# Your max_length is set to 500, but you input_length is only 394. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=197)
# Your max_length is set to 500, but you input_length is only 447. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=223)
# Your max_length is set to 500, but you input_length is only 395. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=197)
# Your max_length is set to 500, but you input_length is only 432. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=216)
# Your max_length is set to 500, but you input_length is only 442. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=221)
# Your max_length is set to 500, but you input_length is only 368. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=184)
#  The contract consists of a purchase order and these general conditions, including the Annex on security measures . If there is any conflict between different provisions in the contract, the following rules must be applied . All documents issued by the contractor are held inapplicable, unless explicitly mentioned in the special conditions of the contract ..  The platform may be used to exchange electronic documents (e-documents) such as electronic invoices between the parties . This is done either through web services, with a machine-to-machine connection between parties, or through a web application (the supplier portal).  The e-PRIOR portal, which allows the contractor to exchange electronic business documents, such as invoices, through a graphical user interface, is updated on a regular basis . Pre-existing material : any material, document, technology or know-how which exists prior to the contractor using it for the production of a result in the performance of the contract ..  If a provision is or becomes illegal, invalid or unenforceable to any extent, it must be severed from the remainder of the contract . This does not affect the legality, validity or enforceability of any other provisions which continue in full force and effect . One member of a group of economic operators is appointed as leader of the group ..  Conformity must be declared only where conditions laid down in the purchase order are satisfied and the supplies conform to the tender specifications . If, for reasons attributable to the contractor, the contracting authority is unable to accept the supplies, the contractor must be notified at the latest by the deadline for conformity ..  Supplies must be guaranteed against all defects in manufacture or materials for two years . Each box must be clearly labelled with the following information: - name of contracting authority and address for delivery, name of contractor; - description of contents; - date of delivery; - number and date of purchase order ..  Contractor must guarantee that any permits and licences required for manufacturing and selling supplies have been obtained . The contractor must replace at its own expense, and within a reasonable time limit, any items which become damaged or defective in the course of normal use during the guarantee period ..  A reduction in price may be imposed, together with liquidated damages under the conditions of Article 15.3.2014 . Contractors who are natural persons are required to provide proof of their status as a selfemployed person . The contractor has 30 days following the date of receipt to submit observations ..  The contractor must not be incorporated into the contracting authority's administrative organisation . Personnel executing tasks assigned to the contractor may not receive orders directly from the . Contractor must ensure that the personnel performing the contract and any future replacement personnel possess the professional qualifications and experience required ..  The parties agree that any communication made by email has full legal effect and is admissible as evidence in judicial proceedings . The contracting authority must take the necessary measures to implement and maintain electronic systems that enable the supplier portal to be used effectively ..  The electronic systems are specified in the Supplier Portal Overview2 and e-Invoicing User Manual . If communication via the supplier portal or the EDI communication, as appropriate, is hindered by factors beyond the control of one party, it must notify the other immediately and the parties must take the necessary measures to restore this communication ..  The parties agree that an invoice, sent via the supplier portal, qualifies as an electronic invoice . The PDF and XML documents generated in relation to the financial document are to be considered as proof of receipt by the contracting authority . All EDI messages exchanged by the parties must be stored by each party, unaltered and securely ..  Th ...

# %%
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer
import torch

# Initialize the tokenizer and model
pegasus_tokenizer = AutoTokenizer.from_pretrained("google/bigbird-pegasus-large-bigpatent")
pegasus_model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-bigpatent")

# Check if a GPU is available and if not, use a CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Move the model to the device
pegasus_model.to(device)
# Out:
# BigBirdPegasusForConditionalGeneration(
#   (model): BigBirdPegasusModel(
#     (shared): Embedding(96103, 1024, padding_idx=0)
#     (encoder): BigBirdPegasusEncoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): BigBirdPegasusLearnedPositionalEmbedding(4096, 1024)
#       (layers): ModuleList(
#         (0-15): 16 x BigBirdPegasusEncoderLayer(
#           (self_attn): BigBirdPegasusEncoderAttention(
#             (self): BigBirdPegasusBlockSparseAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=False)
#               (key): Linear(in_features=1024, out_features=1024, bias=False)
#               (value): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (output): Linear(in_features=1024, out_features=1024, bias=False)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): NewGELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BigBirdPegasusDecoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): BigBirdPegasusLearnedPositionalEmbedding(4096, 1024)
#       (layers): ModuleList(
#         (0-15): 16 x BigBirdPegasusDecoderLayer(
#           (self_attn): BigBirdPegasusDecoderAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           )
#           (activation_fn): NewGELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BigBirdPegasusDecoderAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=96103, bias=False)
# )

# %%
# Use the model to explain the final text
explanation_input = "explain this" + final_text
inputs = pegasus_tokenizer(explanation_input, return_tensors='pt').to(device)
explanation_ids = pegasus_model.generate(
    **inputs,
    max_length=256, 
    do_sample=True, 
    num_beams=5, 
    length_penalty=1.0,
    repetition_penalty=1.4
    )
explanation = pegasus_tokenizer.decode(explanation_ids[0], skip_special_tokens=True)

# Delete the tensors
del inputs
del explanation_ids

# Empty the cache
torch.cuda.empty_cache()
# Out:
# A platform for the exchange of electronic business documents, such as electronic invoices between the parties. The platform may be used either through web services, with a machine-to-machine connection between parties, or through a web application.

# %%
def arrange_text(text):
    # Replace ".." by "."
    text = re.sub(r'\.\.', '.', text)
    # Replace " ." by "."
    text = re.sub(r' \.', '.', text)
    # Return to line after each "."
    text = re.sub(r'\.', '.\n', text)
    # Replace "  " by " " and "   " by " "
    text = re.sub(r' +', ' ', text)
    # Add "•" before the start of any sentence
    text = re.sub(r'(^|\n)([^\n])', r'\1• \2', text)
    # Remove the whole line if it has less than 10 non-space, non-punctuation characters after •
    text = re.sub(r'\n• [^a-zA-Z0-9]*([a-zA-Z0-9][^a-zA-Z0-9]*){0,9}\n', '\n', text)
    # Remove "• " if it is the last line and has two or more spaces after it
    text = re.sub(r'\n•  +\n$', '\n', text)
    # Remove trailing bullet points
    text = re.sub(r'\n•  +$', '', text)
    
    return text

# %%
print(arrange_text(final_text), '\n\n', "\033[1m" + explanation + "\033[0m")
# Out:
# •  The contract consists of a purchase order and these general conditions, including the Annex on security measures.
# •  If there is any conflict between different provisions in the contract, the following rules must be applied.
# •  All documents issued by the contractor are held inapplicable, unless explicitly mentioned in the special conditions of the contract.
# •  The platform may be used to exchange electronic documents (e-documents) such as electronic invoices between the parties.
# •  This is done either through web services, with a machine-to-machine connection between parties, or through a web application (the supplier portal).
# •  The e-PRIOR portal, which allows the contractor to exchange electronic business documents, such as invoices, through a graphical user interface, is updated on a regular basis.
# •  Pre-existing material : any material, document, technology or know-how which exists prior to the contractor using it for the production of a result in the performance of the contract.
# •  If a provision is or becomes illegal, invalid or unenforceable to any extent, it must be severed from the remainder of the contract.
# •  This does not affect the legality, validity or enforceability of any other provisions which continue in full force and effect.
# •  One member of a group of economic operators is appointed as leader of the group.
# •  Conformity must be declared only where conditions laid down in the purchase order are satisfied and the supplies conform to the tender specifications.
# •  If, for reasons attributable to the contractor, the contracting authority is unable to accept the supplies, the contractor must be notified at the latest by the deadline for conformity.
# •  Supplies must be guaranteed against all defects in manufacture or materials for two years.
# •  Each box must be clearly labelled with the following information: - name of contracting authority and address for delivery, name of contractor; - description of contents; - date of delivery; - number and date of purchase order.
# •  Contractor must guarantee that any permits and licences required for manufacturing and selling supplies have been obtained.
# •  The contractor must replace at its own expense, and within a reasonable time limit, any items which become damaged or defective in the course of normal use during the guarantee period.
# •  A reduction in price may be imposed, together with liquidated damages under the conditions of Article 15.
# •  Contractors who are natural persons are required to provide proof of their status as a selfemployed person.
# •  The contractor has 30 days following the date of receipt to submit observations.
# •  The contractor must not be incorporated into the contracting authority's administrative organisation.
# •  Personnel executing tasks assigned to the contractor may not receive orders directly from the.
# •  Contractor must ensure that the personnel performing the contract and any future replacement personnel possess the professional qualifications and experience required.
# •  The parties agree that any communication made by email has full legal effect and is admissible as evidence in judicial proceedings.
# •  The contracting authority must take the necessary measures to implement and maintain electronic systems that enable the supplier portal to be used effectively.
# •  The electronic systems are specified in the Supplier Portal Overview2 and e-Invoicing User Manual.
# •  If communication via the supplier portal or the EDI communication, as appropriate, is hindered by factors beyond the control of one party, it must notify the other immediately and the parties must take the necessary measures to restore this communication.
# •  The parties agree that an invoice, sent via the supplier portal, qualifies as an electronic invoice.
# •  The PDF and XML documents generated in relation to the financial document are to be considered as proof of receipt by the contracting authority.
# •  All EDI messages exchanged by the parties must be stored by each party, unaltered and securely.
# •  The parties must take the necessary measures to implement and maintain safety measures and procedures in order to adequately prevent messages from incurring delays, being corrupted as to content or form, or being lost.
# •  Contractors must take out an insurance policy against risks and damage or loss relating to the performance of the contract.
# •  Contractors must take all the necessary measures to prevent any situation of conflict of interest or professional conflicting interest.
# •  Contractors are not liable for any loss or damage caused to the contractor during or as a consequence of performance of the contract, unless the loss was caused by wilful misconduct or gross negligence of the contracting authority.
# •  Each party must: (a) not use confidential information or documents for any purpose other than to perform its obligations under the contract without the prior written agreement of the other party.
# •  The confidentiality obligations set out in this Article are binding on the contracting authority and the contractor during the performance of the contract.
# •  Contractors have right of recourse at any time to the European Data Protection Supervisor.
# •  Contractors must give personnel access to data to the extent strictly necessary for the performance, management and monitoring of the contract.
# •  Contractor must not subcontract and have contract performed by third parties beyond third parties.
# •  Contractors must ensure that the subcontract does not affect the rights of the contracting authority.
# •  The Union acquires all rights from the moment the contracting authority approves the results delivered by the contractor.
# •  The payment of the price includes any fees payable to the contractor in relation to the acquisition of ownership of rights by the Union.
# •  The Union acquires the rights to the results for the following modes of exploitation.
# •  Modes of exploitation are the results of the Union.
# •  loitation: (a) reproduction: the right to authorise or prohibit direct or indirect, temporary or permanent reproduction.
# •  loitation is a form of reproduction.
# •  permanent reproduction of the results by any means (mechanical, digital or other) and in any form, in w.
# •  permanent reproduction.
# •  The results are published in the U.
# •  version of this article.
# •  The UK has the exclusive right to authorise or prohibit any communications to the public.
# •  The right to communicate to the people has the right to write to them, in whole or in part; (b) The right also has a right to prohibit any communication to be authorised or prohibited.
# •  it any display, performance or communication to the public, by wired or wireless means, including the m.
# •  The making available to the public of the results in such a way that members of the public may access t.
# •  the results.
# •  A person has a right to contact them from a place and at a time individually chosen by them; this right also includes communicatio.
# •  The right to communicate with a person is also a right in the United States.
# •  (c) distribution: the exclusive right to authorise o.
# •  ication and broadcasting by cable or by.
# •  by satellite;.
# •  (c), distribution: The exclusive right of authorising o.
# • Iication and.
# •  broadcasting by satellite or by cable; (C) Distribution: theexclusive right to.
# •  authorise and distribute by cable and satellite; (c-licence).
# •  The results will not be published or published in any form of distribution of results or copies of the results to the public, by sale or by sale.
# •  The results are published in accordance with the law.
# •  (d) rental: the exclusive right to authorise or prohibit rental or lending of the resu.
# •  le le or otherwise; (d), (c) rental : exclusive right of authorising or prohibiting rental.
# •  or prohibiting.
# •  rental of a resuption.
# •  or otherwise.
# •  e results or copies of copies of the results; (e) adaptation: the exclusive right to authorise or prohibit any.
# •  t any modification of the results; (f) translation: the exclusive right to authorise or prohibit any.
# •  or prohibit.
# •  t any modifications of the.
# •  (f), translation: a translation.
# •  of translation.
# •  Any translation, adaptation, arrangement, arrangement or creation of derivative works based on the results of the results, and any translation of those works.
# •  d any other alteration of the results, subject to the respect of the moral rights of authors, where applica.
# •  d any else alteration of.
# •  the results.
# •  Subject to the.
# •  respect of moral.
# •  rights of the authors, who have moral rights to.
# •  say they are not responsible for the content content.
# •  (g) where the results are or include a database: the exclusive right to authorise or prohibi.
# •  pplicable; (g), where results are.
# •  a database.
# •  The exclusive right of authorising or prohibiting or authorising or prohibiting such actions is prohibited.
# •  The exclusivity of a database is forbidden.
# •  rohibit the extraction of all or a substantial part of the contents of the database to another medium by rohibit.
# •  ium by any means or in any form; and the exclusive right to authorise or prohibit the reutilisation of a.
# •  The exclusive right of authorising or prohibiting the.
# •  reutilising of a reutilised ium.
# •  any means of re-use of a.
# •  ium, or the right to.
# •  prohibit the.
# •  use of a ium in any way;.
# •  Authorising or banning the re-utilisation.
# •  n of all or a substantial part of the contents of the database by the distribution of copies of copies, by renting or renting.
# •  enting, by online or other forms of transmission; (h) where the results are or include patentable subje.
# •  enting is a form of transmission that includes the results of or including patentable.
# •  subjeing, (h), where the result is or includes patentable.
# •  or where results are.
# •  or include patents;.
# •  where results or.
# •  include patentizable subjections;.
# •  results are.
# •  where the.
# •  results or include Patentable subjumps;.
# •  Subject-matter: the right to register them as a patent and to further exploit such a patent to the full.
# •  subject-matter.
# •  subject matter.
# •  e fullest extent; (i) where the results are.
# •  or include logos or subject-matter which could be registere which could.
# •  registere.
# •  (I) where results are or include.
# •  logos or subjects which are subject to registere, e.
# •  may not be registered to the fullest extent.
# •  where the result is or.
# •  include logos.
# •  or (i)" where the.
# •  or include logo or subject matter which could have been registere.
# •  The right to register that logo or subject-matter as a trademark and to further trademark it is a trademark.
# •  Trademark registration is a form of registration of a trademark or registration of an item to be trademarked.
# •  rther exploit and use it; (j) where the results are or include know-how: the right to use such knowledge-how.
# •  w-how as necessary to make use of the results to the full extent provided for by the contract, and th.
# •  w-How as necessary.
# •  Contractors have the right to make it available to contractors or subcontractors acting on behalf of the contracting.
# •  Contractors are entitled to have access to the content of their contracts.
# •  Acting authority, subject to their signing of adequate confidentiality undertakings where necessary;.
# •  acting authority.
# •  acting authority,.
# •  their.
# •  adequate confidentiality.
# •  undertakings.
# •  where necessary.
# •  17 EN (k) where the results are documents: the right to store and archive the results in line with the results.
# •  Document management rules applicable to the contracting authority apply to document management rules, including digitisation or digitisation.
# •  Contractors must comply with the rules, such as digitisation and digitisation of documents.
# •  on or converting the format for preservation or new use purposes; (l) where the results are or where the result is or where it is.
# •  on or converted for preservation, (l), or converting for preservation purposes;.
# •  or converting.
# •  preservation or.
# •  use purposes, or converting formats for preservation.
# •  Corporate software, including source code, object code and documentation, is available in the U.
# •  corporate software.
# •  The software includes source code and object code, and documentation.
# •  Article: (i) end-user r.
# •  ratory materials and manuals, in addition to the other.
# •  other rights mentioned in this Article: End-user rights.
# •  User rights, for all uses by the Union or by subcontractors which result from the contract, are user rights.
# •  m the intention of the parties; (ii) the rights to decompile or disassemble the software; (m) to the ext ext ext.
# •  The parties have the right to have the permission of decompiling or disassembling the software.
# •  The right for the contracting authority, except for the contractor may invoke moral rights, is the right to the authority of the contractor, except the contractor invokes moral rights.
# •  xcept where otherwise provided in the contract, to publish the results with or without mentioning the n.
# •  xcept unless otherwise provided, to do so.
# •  xcept that results are published without mentioning n.
# •  the name(s) of the creator(s), and the right to decide when and whether the results may be disclosed.
# •  The results of this article are subject to the right of disclosure.
# •  sed and published and published.
# •  sed and publish.
# •  and published.
# •  publish.
# •  and publish.
# •  sed sedated.
# •  sedated and published in the United States.
# •  Contractor warrants exclusive rights and the modes of exploitation may be exercised by the Union on all parts of the results, irrespective of whether they are created by the contractor or consist of pre-existing materials.
# •  Contractor must establish a list of all rights to the results of the contract or parts thereof.
# •  Documentary evidence must include the name and version number of a software product.
# •  Contractor also warrants that it possesses the relevant rights or powers to execute the transfer and that it has paid all due fees.
# •  If natural persons appear in a result or their voice or any other private element is recorded in a recognisable manner, the contractor must obtain a statement by these persons (or, in the case of minors, by the persons exercising parental authority) giving their permission for the described use of their image, voice or private element.
# •  Contractors must take necessary measures to obtain such consent in accordance with the applicable legal provisions.
# •  Contractors must take all necessary measures to limit any damage due to force majeure.
# •  Parties agree amount payable under this Article is not a penalty and represents a reasonable estimate of fair compensation.
# •  Contractors must notify the contracting authority as soon as it is able to resume performance of the contract.
# •  Contractors are not entitled to compensation for suspension of any part of contract.
# •  Suspension takes effect on the date of formal notification.
# •  Contracting authority may terminate the contract in the following circumstances.
# •  Contractors are unable to obtain any permit or licence required for performance of the contract.
# •  Contractor is unable to perform contract in accordance with tender specifications.
# •  Contractors must formally notify the other party of its intention to terminate the contract and the grounds for termination.
# •  The other party has 30 days following the date of receipt to submit observations, including the measures it has taken to continue fulfilling its contractual obligations.
# •  The decision to terminate becomes enforceable the day after the time limit for submitting observations has elapsed.
# •  Contractor is liable for damage incurred by the contracting authority as a result of the termination of the contract, including the cost of appointing another contractor to provide or complete the services.
# •  Contractor must provide assistance at no additional cost, unless it can demonstrate that it requires substantial additional resources or means.
# •  The contracting authority is exempt from all taxes and duties, including VAT.
# •  Payments must be made within 30 days of receipt of the invoice.
# •  Payments are made in euros or in the currency provided for in the purchase order.
# •  Contractors must pay within 60 days of the end of the period of provision of the services.
# •  Contracting authority must notify contractor (or leader in the case of a joint tender) as soon as possible of any such suspension, giving the reasons for it.
# •  Suspension takes effect on the date the contracting authority sends the notification.
# •  The remaining payment period resumes from the date on which requested information or revised documents are received or the necessary further verification is carried out.
# •  Contractor must repay the contracting authority the amount in question.
# •  Contractors must pay in accordance with the provisions specified in the debit note.
# •  Interest on late payment bears interest at the rate indicated in Article 19.
# •  The contracting authority and the European Anti-Fraud Office (OLAF) may check or require an audit on the performance of the contract.
# •  The audit procedure is initiated on the date of receipt of the relevant letter.
# •  The contractor must keep all original documents stored on any appropriate medium, including digitised originals.
# •  In accordance with Council Regulation (Euratom, EC) No 2185/96 of 11 November 1996 concerning on-the-spot checks and inspections carried out by the Commission in order to protect the European Communities financial interests against fraud and other irregularities.
# •  Findings arising from an investigation may lead to criminal prosecution under national law.
# •  Council Decision 2013/488/EU of 23 September 2013 on the security rules for protecting EU classified information.
# •  Access passes are issued to the holder in person on production of: (a) proof of identity, i.
# •  a document bearing a photograph, such as a national identity card or passport.
# •  Passes must be worn visibly at all times on the contracting authority's premises.
# •  Access passes must be worn visibly at all times on the contracting authority's premises.
# •  Contractors vehicles may only use the entrance to the Justus Lipsius (JL) building.
# •  Passengers without a permanent pass will be refused access at the car park entrance.
# •  Headroom in the car parks is generally limited to 2.
# •  Drivers wishing to enter the car park with a higher vehicle must first consult the Accreditation Service.
# •  Persons with reduced mobility may request a reserved parking space.
#
#
#  A platform for the exchange of electronic business documents, such as electronic invoices between the parties. The platform may be used either through web services, with a machine-to-machine connection between parties, or through a web application.

# %%
from transformers import BertTokenizerFast, pipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer
import torch
import re

# %%
# Initialize Bert summarizer & tokenizer
bert_tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")
bert_summarizer = pipeline("summarization", device=0)

# Measure the length of a text
def bert_len(text):
    tokens = bert_tokenizer.encode(
        text,
        add_special_tokens=True,
        max_length=len(text),
        truncation=True
    )
    return len(tokens)

# Text splitter initialization
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,  
    chunk_overlap=30,
    length_function=bert_len,
    separators=[". ", ""]
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
# Remove duplicate sentences from the text 
def remove_duplicates(text):
    seen = set()
    return ". ".join([sentence for sentence in text.split(". ") if sentence not in seen and not seen.add(sentence)])

# Summarize a text
def generate_summary(text):  
    summary = bert_summarizer(text, max_length=500, min_length=25, do_sample=False)
    return summary[0]['summary_text']

# Join the chunks together and summarize them
def summarize_chunks(text):
    chunks = text_splitter.split_text(text)
    chunk_summaries = [generate_summary(chunk) for chunk in chunks]
    text = ". ".join(chunk_summaries)
    text = remove_duplicates(text)
    return text

# Arrange the summary
def arrange_text(text):
    # Replace ".." by "."
    text = re.sub(r'\.\.', '.', text)
    # Replace " ." by "."
    text = re.sub(r' \.', '.', text)
    # Return to line after each "."
    text = re.sub(r'\.', '.\n', text)
    # Replace "  " by " " and "   " by " "
    text = re.sub(r' +', ' ', text)
    # Add "•" before the start of any sentence
    text = re.sub(r'(^|\n)([^\n])', r'\1• \2', text)
    # Remove the whole line if it has less than 10 non-space, non-punctuation characters after •
    text = re.sub(r'\n• [^a-zA-Z0-9]*([a-zA-Z0-9][^a-zA-Z0-9]*){0,9}\n', '\n', text)
    # Remove "• " if it is the last line and has two or more spaces after it
    text = re.sub(r'\n•  +\n$', '\n', text)
    # Remove trailing bullet points
    text = re.sub(r'\n•  +$', '', text)
    return text

def generate_explanation(final_text, device='cuda'):
    # Initialize the model & tokenizer
    pegasus_tokenizer = AutoTokenizer.from_pretrained("google/bigbird-pegasus-large-bigpatent")
    pegasus_model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-bigpatent")
    
    # Check if a GPU is available and if not, use a CPU
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Move the model to the device
    pegasus_model.to(device)

    # Define the inputs
    explanation_input = "explain this " + final_text
    inputs = pegasus_tokenizer(explanation_input, return_tensors='pt').to(device)

    explanation_ids = pegasus_model.generate(
        **inputs,
        max_length=256, 
        do_sample=True, 
        num_beams=5, 
        length_penalty=1.0,
        repetition_penalty=1.4
    )

    explanation = pegasus_tokenizer.decode(explanation_ids[0], skip_special_tokens=True)
    
    # Delete the tensors
    del inputs
    del explanation_ids
    
    # Empty the cache
    torch.cuda.empty_cache()

    return arrange_text(final_text), '\n\n', "\033[1m" + explanation + "\033[0m"

def summarize_doc(text):
    text = summarize_chunks(text)
    # Check if the summarized text length is over 4000 words
    while len(text.split()) > 4000:
        text = summarize_chunks(text)
    
    text = generate_explanation(text)
    print(*text)

# %%
with open('../data/text_l2.txt') as f:
    test = f.read()

# %%
test = summarize_doc(test)
# Out:
# Your max_length is set to 500, but you input_length is only 480. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=240)
# Your max_length is set to 500, but you input_length is only 487. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=243)
# Your max_length is set to 500, but you input_length is only 495. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=247)
# Your max_length is set to 500, but you input_length is only 471. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=235)
# Your max_length is set to 500, but you input_length is only 485. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=242)
# Your max_length is set to 500, but you input_length is only 436. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=218)
# Your max_length is set to 500, but you input_length is only 482. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=241)
# Your max_length is set to 500, but you input_length is only 457. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=228)
# Your max_length is set to 500, but you input_length is only 477. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=238)
# Your max_length is set to 500, but you input_length is only 345. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=172)
# Attention type 'block_sparse' is not possible if sequence_length: 662 <= num global tokens: 2 * config.block_size + min. num sliding tokens: 3 * config.block_size + config.num_random_blocks * config.block_size + additional buffer: config.num_random_blocks * config.block_size = 704 with config.block_size = 64, config.num_random_blocks = 3. Changing attention type to 'original_full'...
# •  Nike's privacy policy explains how your data is used, shared and protected.
# •  It also explains what choices you have relating to your personal data and how you can contact us.
# •  Who is responsible for processing of your data will depend on how you interact with Nike's Platform.
# •  Nike does not allow children to register on our Platform when they are under the legal age limit of the country in which they reside.
# •  We use your personal data in the following ways:To provide the features of the Platform and Services You Request.
# •  To provide features of our Platform, we will use your data to provide the requested product or service.
# •  If you use our Platform to track your fitness activity or physical characteristics, we will collect this personal data and store it so that you can review it in the Platform.
# •  Your fitness activity data may include data you enter about your activity or data collected by your device during your activity.
# •  Nike collects data about your fitness activity or your physical characteristics, together, “Workout Info”, to provide services on our Platform.
# •  We may also use personal data about how you use our Platform to prevent, detect or investigate fraud, abuse, illegal use, violations of our Terms of Use and comply with court orders, governmental requests or applicable law.
# •  Nike will use the personal data to personalize your experience on the Nike Platform and, if you have given your consent, send you personalized marketing communications.
# •  We use this data to build the Partner Orders page shown in your Nike account and give you access to selected benefits.
# •  We use third parties to protect your data to prevent illegal uses of our Platform or violations of our Terms of Use and our policies.
# •  You may opt-out of personalized advertising and custom audiences by using the relevant settings in our Platform.
# •  Some of the data recipients with whom Nike shares your personal data may be located in countries other than the country in which your data originally was collected.
# •  We take measures to comply with applicable legal requirements for the transfer of personal data to recipients in countries outside of the EEA, UK or Switzerland that do not provide an adequate level of data protection.
# •  You can opt-out of receiving Nike’s marketing communications by modifying your preferences in the "view or change my profile" section of our Sites.
# •  Nike collects information, which may include personal data, from your browser when you use our Platform.
# •  We use cookies and pixel tags to track our customers’ usage of the Platform.
# •  There are generally three categories of cookies used on our Platform: functional, social, performance and advertising.
# •  These cookies are required for basic site functionality and are always enabled.
# •  Refusing these cookies may result in poorly-tailored recommendations and slow site performance.
# •  You can also choose to have your computer warn you each time a cookie is being sent, or you can choose to turn off all cookies.
# •  These ad services may also track your online activities over time and across multiple websites and apps.
# •  Nike's privacy policy was last modified in November 2022.
# •  If we decide to update our privacy policy, we will post the changes on our Platform.
# •  If you wish to provide feedback or if you have questions, please use our Nike Privacy Webform.
#
#
#  This patent describes how to use, share and protect your personal data. It also describes what choices you have relating to your personal data and how you can contact us.
